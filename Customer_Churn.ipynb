# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    customerID gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG    NaN            NaN  ...          29.85        29.85     No
# 1  5575-GNVDE    NaN            NaN  ...          56.95       1889.5     No
# 2  3668-QPYBK    NaN            NaN  ...          53.85       108.15    Yes
# 3  7795-CFOCW    NaN            NaN  ...          42.30      1840.75     No
# 4  9237-HQITU    NaN            NaN  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            6034 non-null   object
#  2   SeniorCitizen     6034 non-null   float64
#  3   Partner           6034 non-null   object
#  4   Dependents        6034 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     6034 non-null   object
#  8   InternetService   6034 non-null   object
#  9   OnlineSecurity    6034 non-null   object
#  10  OnlineBackup      6034 non-null   object
#  11  DeviceProtection  6034 non-null   object
#  12  TechSupport       6034 non-null   object
#  13  StreamingTV       6034 non-null   object
#  14  StreamingMovies   6034 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Drop missing value

# %%
#When I try to cek every feature that has missing value, all off the have same missing value possition
#the missing value data start from index 0-1008 (1009), so I drop the row
# df_cekNaN=df[df['gender'].isnull()]
# df_cekNaN

# %%
#drop missing value row
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6034 entries, 1009 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        6034 non-null   object
#  1   gender            6034 non-null   object
#  2   SeniorCitizen     6034 non-null   float64
#  3   Partner           6034 non-null   object
#  4   Dependents        6034 non-null   object
#  5   tenure            6034 non-null   int64
#  6   PhoneService      6034 non-null   object
#  7   MultipleLines     6034 non-null   object
#  8   InternetService   6034 non-null   object
#  9   OnlineSecurity    6034 non-null   object
#  10  OnlineBackup      6034 non-null   object
#  11  DeviceProtection  6034 non-null   object
#  12  TechSupport       6034 non-null   object
#  13  StreamingTV       6034 non-null   object
#  14  StreamingMovies   6034 non-null   object
#  15  Contract          6034 non-null   object
#  16  PaperlessBilling  6034 non-null   object
#  17  PaymentMethod     6034 non-null   object
#  18  MonthlyCharges    6034 non-null   float64
#  19  TotalCharges      6034 non-null   object
#  20  Churn             6034 non-null   object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Mapping categorical Data

# %%
#gender
ax = df.gender.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['gender'] =df['gender'].map({'Male':0,'Female':1})

# %%
#SeniorCitizen
ax = df.SeniorCitizen.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
#Partner
ax = df.Partner.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Partner']=df['Partner'].map({'No':0,'Yes':1})

# %%
#Dependents
ax = df.Dependents.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Dependents']=df['Dependents'].map({'No':0, 'Yes':1})

# %%
#tenure
df['tenure'] = df['tenure'].astype(float)
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['tenure'])
plt.show()

# %%
#PhoneService
ax = df.PhoneService.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['PhoneService']=df['PhoneService'].map({'No':0, 'Yes':1})

# %%
#MultipleLines
ax = df.MultipleLines.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['MultipleLines']=df['MultipleLines'].map({'No phone service':0, 'No':1, 'Yes':2})

# %%
#InternetService
ax = df.InternetService.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['InternetService']=df['InternetService'].map({'No':0, 'DSL':1, 'Fiber optic':2})

# %%
#OnlineSecurity
ax = df.OnlineSecurity.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['OnlineSecurity']=df['OnlineSecurity'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#OnlineBackup
ax = df.OnlineBackup.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['OnlineBackup']=df['OnlineBackup'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#DeviceProtection
ax = df.DeviceProtection.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['DeviceProtection']=df['DeviceProtection'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#TechSupport
ax = df.TechSupport.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['TechSupport']=df['TechSupport'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#StreamingTV
ax = df.StreamingTV.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['StreamingTV']=df['StreamingTV'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#StreamingMovies
ax = df.StreamingMovies.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['StreamingMovies']=df['StreamingMovies'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#Contract
ax = df.Contract.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Contract']=df['Contract'].map({'Month-to-month':0, 'One year':1, 'Two year':2})

# %%
#PaperlessBilling
ax = df.PaperlessBilling.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['PaperlessBilling']=df['PaperlessBilling'].map({'No':0, 'Yes':1})

# %%
#PaymentMethod
ax = df.PaymentMethod.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['PaymentMethod']=df['PaymentMethod'].map({'Electronic check':0, 'Mailed check':1, 'Bank transfer (automatic)':2, 'Credit card (automatic)':3})

# %%
#MonthlyCharges
df['MonthlyCharges'] = df['MonthlyCharges'].astype(float)
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['MonthlyCharges'])
plt.show()

# %%
#TotalCharges
#I got an error in this feature when I check, some features have null value like " ", 
#so I changed it first
df["TotalCharges"] = df["TotalCharges"].replace(" ", 0)

df['TotalCharges'] = df['TotalCharges'].astype(float)
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['TotalCharges'])
plt.show()

# %%
#Churn
ax = df.Churn.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Churn']=df['Churn'].map({'No':0, 'Yes':1})

# %%
df.head()
# Out:
#       customerID  gender  SeniorCitizen  ...  MonthlyCharges  TotalCharges  Churn
# 1009  6419-ZTTLE       0            1.0  ...           20.75        485.20      0
# 1010  0929-HYQEW       0            0.0  ...           50.15        160.85      0
# 1011  6614-YOLAC       1            0.0  ...           58.65       4145.25      0
# 1012  7426-RHZGU       0            0.0  ...           95.90        827.45      0
# 1013  4065-JJAVA       1            0.0  ...           49.50         49.50      0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Check Feature Correlation

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")

# %%
df.corr()['Churn'].sort_values(ascending=False)
# Out:
# Churn               1.000000
# InternetService     0.319769
# PaperlessBilling    0.199713
# MonthlyCharges      0.197367
# StreamingTV         0.171273
# StreamingMovies     0.164506
# SeniorCitizen       0.153286
# DeviceProtection    0.085889
# OnlineBackup        0.073721
# MultipleLines       0.041299
# TechSupport         0.034553
# OnlineSecurity      0.024750
# PhoneService        0.012583
# gender              0.006294
# Partner            -0.152223
# Dependents         -0.161191
# TotalCharges       -0.194529
# PaymentMethod      -0.253851
# tenure             -0.352140
# Contract           -0.394333
# Name: Churn, dtype: float64

# %% [markdown]
# ### Balancing the data

# %%
df['Churn'].value_counts()
# Out:
# 0    4426
# 1    1608
# Name: Churn, dtype: int64

# %%
from sklearn.utils import resample

fraud = df[df['Churn'] ==0]
not_fraud = df[df['Churn'] == 1]

balance_data = resample(fraud,
                        replace=True,
                        n_samples = len(not_fraud),
                        random_state=50)
df_balance = pd.concat([not_fraud, balance_data])
df_balance.Churn.value_counts()
# Out:
# 1    1608
# 0    1608
# Name: Churn, dtype: int64

# %% [markdown]
# ### Shuffle the Data

# %%
df_balance = df_balance.sample(frac=1)

# %% [markdown]
# ### Normalization

# %%
df_feature = df_balance.drop(['Churn','customerID'], axis=1)
df_label = df_balance['Churn']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df_feature)
df_feature_scaler = scaler.transform(df_feature) #return in ndarray

#convert to dataframe
df_feature_scaler = pd.DataFrame(data=df_feature_scaler,columns=df_feature.columns)
df_feature_scaler.head()
# Out:
#      gender  SeniorCitizen  ...  MonthlyCharges  TotalCharges
# 0 -1.008118      -0.495526  ...        0.431753     -0.475699
# 1 -1.008118       2.018057  ...        0.913574      1.318273
# 2 -1.008118      -0.495526  ...       -0.095293      0.806074
# 3 -1.008118      -0.495526  ...        0.621351     -0.122515
# 4 -1.008118      -0.495526  ...       -1.674693     -0.353091
#
# [5 rows x 19 columns]

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_feature_scaler, df_label, test_size=0.2, random_state=27)

# %% [markdown]
# ## Classification Using Sklearn

# %% [markdown]
# ### Grid Search CV Ensemble Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
params = {'min_samples_leaf':[1,2,3],
          'min_samples_split':[2,3,4,5],
          'min_weight_fraction_leaf':[0.0,0.04,0.07],
          'n_estimators':[115,125,135],
          'criterion':['gini','entropy'],
          'class_weight':['None','balanced'],
          'max_features':['auto', 'sqrt', 'log2']}
model = RandomForestClassifier()
gsc = GridSearchCV(model, params, scoring='roc_auc', cv=5, return_train_score=True, n_jobs = 10)

# %% [markdown]
# ### Grid Search CV Learning and get best parameter

# %%
gsc.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,...
#              iid='deprecated', n_jobs=10,
#              param_grid={'class_weight': ['None', 'balanced'],
#                          'criterion': ['gini', 'entropy'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'min_weight_fraction_leaf': [0.0, 0.04, 0.07],
#                          'n_estimators': [115, 125, 135]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='roc_auc', verbose=0)

# %%
print(gsc.best_params_)
print(gsc.best_score_)
# Out:
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 4, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 125}
# 0.8490003655584507

# %% [markdown]
# ### Learning Model "RandomForest"

# %%
model = RandomForestClassifier(class_weight = 'balanced',
                               criterion = 'gini', 
                               max_features = 'auto',
                               min_samples_leaf = 3, 
                               min_samples_split = 4, 
                               min_weight_fraction_leaf = 0.0, 
                               n_estimators = 125)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=3, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, n_estimators=125,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
model.score(X_train, y_train)
# Out:
# 0.8998541565386485

# %%
from sklearn.metrics import accuracy_score
test_pred = model.predict(X_test)
accuracy_score(test_pred, y_test)
# Out:
# 0.7732919254658385

# %% [markdown]
# ### Grid Search CV SVM

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
params = {'C': [1,2,3],
          'kernel': ['linear', 'poly', 'rbf'],
          'gamma':['scale','auto'],
          'class_weight':['None', 'dict', 'balanced']}
model = svm.SVC()
gsc_svm = GridSearchCV(model, params, scoring='roc_auc', cv=5, return_train_score=True, n_jobs = 5)

# %% [markdown]
# ### Grid Search CV Learning and get best parameter

# %%
gsc_svm.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=5,
#              param_grid={'C': [1, 2, 3],
#                          'class_weight': ['None', 'dict', 'balanced'],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='roc_auc', verbose=0)

# %%
print(gsc_svm.best_params_)
print(gsc_svm.best_score_)
# Out:
# {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'linear'}
# 0.8381600908944661

# %% [markdown]
# ### Learning Model "SVM"

# %%
model = svm.SVC(C = 1,
                class_weight = 'balanced', 
                gamma = 'scale', 
                kernel = 'linear')

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
model.score(X_train, y_train)
# Out:
# 0.7496353913466213

# %%
from sklearn.metrics import accuracy_score
test_pred = model.predict(X_test)
accuracy_score(test_pred, y_test)
# Out:
# 0.7391304347826086

# %%
x = pd.DataFrame()
x['feature'] = df_feature.columns 
x['corelation'] = np.array(model.coef_)[0]
x.sort_values(by=['corelation'], ascending=False)
# Out:
#              feature  corelation
# 7    InternetService    0.828641
# 18      TotalCharges    0.586892
# 12       StreamingTV    0.287811
# 13   StreamingMovies    0.256621
# 6      MultipleLines    0.162836
# 15  PaperlessBilling    0.119476
# 9       OnlineBackup    0.043283
# 2            Partner    0.041813
# 10  DeviceProtection   -0.009447
# 1      SeniorCitizen   -0.009672
# 5       PhoneService   -0.035238
# 11       TechSupport   -0.052953
# 0             gender   -0.055772
# 3         Dependents   -0.089567
# 16     PaymentMethod   -0.108715
# 8     OnlineSecurity   -0.138454
# 14          Contract   -0.473002
# 17    MonthlyCharges   -0.739115
# 4             tenure   -1.037618

# %% [markdown]
# ## Deep Learning Classification Using CNN

# %% [markdown]
# ### Split data into train(train, validation) and test

# %%
from sklearn.model_selection import train_test_split

X_big, X_test, y_big, y_test = train_test_split(df_feature_scaler, df_label, test_size=0.2, random_state=27)
#becase the data isn't too much, so I take the validation data from train data
X_train, X_val, y_train, y_val = train_test_split(X_big, y_big, test_size=0.2, random_state=27)

# %%
print(X_big.shape, X_val.shape, X_test.shape)
# Out:
# (2572, 19) (515, 19) (644, 19)

# %% [markdown]
# ### Save data to NPZ format

# %%
np.savez('telco_train', inputs=X_train, targets=y_train)
np.savez('telco_val', inputs=X_val, targets=y_val)
np.savez('telco_test', inputs=X_test, targets=y_test)

# %% [markdown]
# ### Load NPZ data

# %%
npz_train = np.load('telco_train.npz')
train_inputs, train_targets = npz_train['inputs'].astype(np.float), npz_train['targets'].astype(int)

npz_val = np.load('telco_val.npz')
val_inputs, val_targets = npz_val['inputs'].astype(np.float), npz_val['targets'].astype(int)

npz_test = np.load('telco_test.npz')
test_inputs, test_targets = npz_test['inputs'].astype(np.float), npz_test['targets'].astype(int)

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
hidden_layer_size = 150
output_size = 2 #0 and 1

#3 hidden layer, depth 100
model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])

#optimizer
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)
history = model.fit(train_inputs,
          train_targets,
          batch_size = 200,
          epochs = 20,
          callbacks = [early_stopping],
          validation_data = (val_inputs, val_targets),
          verbose = 2)
# Out:
# Epoch 1/20
# 11/11 - 0s - loss: 0.6179 - accuracy: 0.6563 - val_loss: 0.5137 - val_accuracy: 0.7612
# Epoch 2/20
# 11/11 - 0s - loss: 0.5048 - accuracy: 0.7477 - val_loss: 0.5190 - val_accuracy: 0.7650
# Epoch 3/20
# 11/11 - 0s - loss: 0.4871 - accuracy: 0.7564 - val_loss: 0.5003 - val_accuracy: 0.7670
# Epoch 4/20
# 11/11 - 0s - loss: 0.4741 - accuracy: 0.7657 - val_loss: 0.5079 - val_accuracy: 0.7650
# Epoch 5/20
# 11/11 - 0s - loss: 0.4684 - accuracy: 0.7676 - val_loss: 0.5063 - val_accuracy: 0.7650

# %%
def plot_learningCurve(history, epochs):
  epoch_range = range(1, epochs+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

  plt.plot(epoch_range, history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

# %%
plot_learningCurve(history, 5)

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print("Test loss: {0:.2f} and Test accuracy: {1:.2f}% ".format(test_loss,test_accuracy*100))
# Out:
# 21/21 [==============================] - 0s 1ms/step - loss: 0.5010 - accuracy: 0.7516
# Test loss: 0.50 and Test accuracy: 75.16%
